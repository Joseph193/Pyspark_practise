# %%
dbutils.widgets.text("file_name", "")

# %%
file_name = dbutils.widgets.get("file_name")
file_name

# %%
df = spark.read.format("csv").option("header", "true").load(f"/Volumes/ingestion_catalog/ingestion_schema/source/{file_name}.csv")
display(df)

# %%
df.write.format("csv").mode("append").save(f"/Volumes/ingestion_catalog/ingestion_schema/destination/{file_name}")
